# %%
# 344. 翻转字符串
class Solution(object):
    def reverseString(self, s):
        """
        :type s: List[str]
        :rtype: None Do not return anything, modify s in-place instead.
        """
        left = 0
        right = len(s) - 1
        while left < right:
            s[left], s[right] = s[right], s[left]
            left += 1
            right -= 1
        return s

# %%
# 541. 反转字符串 II(美团面试题)
class Solution(object):
    def reverseStr(self, s, k):
        """
        :type s: str
        :type k: int
        :rtype: str
        """
        sList = list(s)
        def reversed(sList, left, right):
            while left < right:
                sList[left], sList[right] = sList[right], sList[left]
                left += 1
                right -= 1
        for i in range(0, len(sList), 2 * k):
            reversed(sList, i, min(i + k - 1, len(sList) - 1))
        result = ''.join(sList)
        return result

# %%
# 54.替换数字

class Solution(object):
    def subsitute_numbers(self, s):
        numberNum = 0
        for i in s:
            if i >= '0' and i <= '9':
                numberNum += 1
        s = list(s)
        left = len(s) - 1
        # print(left)
        s.extend(' ' for _ in range(numberNum * 5))
        right = len(s) - 1
        # print(right)
        while left >= 0:
            if s[left] >= 'a' and s[left] <= 'z':
                s[right] = s[left]
                left -= 1
                right -= 1
            else:
                for ch in "rebmun":
                    s[right] = ch
                    right -= 1
                left -= 1
        return ''.join(s)
            




if __name__ == "__main__":
    solution = Solution()

    while True:
        try:
            s = input()
            result = solution.subsitute_numbers(s)
            print(result)
        except EOFError:
            break
# Out:
# numbernumbernumber
# number
# eos

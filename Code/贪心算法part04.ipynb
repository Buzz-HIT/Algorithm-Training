# %%
# 452
class Solution(object):
    def findMinArrowShots(self, points):
        """
        :type points: List[List[int]]
        :rtype: int
        """
        if len(points) == 0:
            return 0
        points.sort(key=lambda x: x[0])
        minRight = points[0][1]
        result = 1
        for i in range(1, len(points)):
            if points[i][0] > minRight:
                result += 1
                minRight = points[i][1]
            else:
                minRight = min(minRight, points[i][1])
        return result

# %%
# 453.
class Solution(object):
    def eraseOverlapIntervals(self, intervals):
        """
        :type intervals: List[List[int]]
        :rtype: int
        """
        if len(intervals) == 0:
            return 0
        intervals.sort(key=lambda x : x[0])
        curRight = intervals[0][1]
        result = 0
        for i in range(1, len(intervals)):
            if intervals[i][0] >= curRight:
                curRight = intervals[i][1]
            else:
                result += 1
                curRight = min(intervals[i][1], curRight)
        return result

# %%
class Solution(object):
    def partitionLabels(self, s):
        """
        :type s: str
        :rtype: List[int]
        """
        hashLabel = [0] * 26
        s = list(s)
        for i in range(len(s)):
            hashLabel[ord(s[i]) - 97] = i
        result = []
        maxRight = 0
        left = 0
        for i in range(len(s)):
            maxRight = max(maxRight, hashLabel[ord(s[i]) - 97])
            if i == maxRight:
                result.append(i - left + 1)
                left = i + 1
        return result
